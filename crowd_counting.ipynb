# %% [markdown]
# <a href="https://colab.research.google.com/github/k4keshav-singh/Crowd-Counting/blob/main/crowd_counting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics opencv-python
from ultralytics import YOLO # Import the YOLO class from ultralytics

def load_model(model_name='yolov8n.pt'):
    model = YOLO(model_name)
    return model

# ... (rest of your code remains the same) ...
# Out:
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !pip install ultralytics opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 982.4/982.4 kB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
def load_model(model_name='yolov8n.pt'):
    model = YOLO(model_name)
    return model

# %%
def load_image(image_path):
    img = cv2.imread(image_path)
    if img is None:
        raise FileNotFoundError(f"Image not found: {image_path}")
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img, img_rgb

def show_image(img, title='Image'):
    plt.imshow(img)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
def count_people(model, img):
    results = model(img)
    person_count = sum(1 for box in results[0].boxes if int(box.cls[0]) == 0)
    return results, person_count

# %%
def show_annotated_image(results, person_count):
    annotated = results[0].plot()
    plt.figure(figsize=(10, 8))
    plt.imshow(annotated)
    plt.title(f"People Count: {person_count}")
    plt.axis('off')
    plt.show()

# %%
# !pip install opencv-python
import cv2 # Import the cv2 module

def load_image(image_path):
    img = cv2.imread(image_path)
    if img is None:
        raise FileNotFoundError(f"Image not found: {image_path}")
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img, img_rgb

# ... (rest of your code remains the same) ...

# %%
model = load_model()

img, img_rgb = load_image(r"C:\Users\Keshav Singh\Downloads\crowd.png")
show_image(img_rgb, "Original Image")

results, count = count_people(model, img)
print("Detected People:", count)

show_annotated_image(results, count)
results, count = count_people(model, img)
print("Detected People:", count)

show_annotated_image(results, count)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-42444b4332ae> in <cell line: 0>()
#       1 model = load_model()
#       2
# ----> 3 img, img_rgb = load_image(r"C:\Users\Keshav Singh\Downloads\crowd.png")
#       4 show_image(img_rgb, "Original Image")
#       5
#
# <ipython-input-13-34ca7242e11c> in load_image(image_path)
#       5     img = cv2.imread(image_path)
#       6     if img is None:
# ----> 7         raise FileNotFoundError(f"Image not found: {image_path}")
#       8     img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       9     return img, img_rgb
#
# FileNotFoundError: Image not found: C:\Users\Keshav Singh\Downloads\crowd.png

# %%
model = load_model()

img, img_rgb = load_image('crowd_2.png')
show_image(img_rgb, "Original Image")

results, count = count_people(model, img)
print("Detected People:", count)

show_annotated_image(results, count)
# Out:
# 0: 224x640 18 persons, 1 backpack, 96.3ms
# Speed: 3.2ms preprocess, 96.3ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 640)
# Detected People: 18
